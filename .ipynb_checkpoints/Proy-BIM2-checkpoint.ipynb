# %%
import pandas as pd
import json
from pandas import json_normalize
from SPARQLWrapper import SPARQLWrapper, JSON
from rdflib import Graph
from rdflib.namespace import FOAF, RDF

# %% [markdown]
# ## MODELO DE LOS DATOS
# La ontología-conferencia es una nueva ontología autónoma para modelar el conocimiento sobre las conferencias. La ontología de conferencia adopta las mejores prácticas de diseño de ontologías (p. ej., patrones de diseño de ontologías, reutilización e interconexión de ontologías) y garantiza la interoperabilidad con la ontología SWC y todos los demás vocabularios pertinentes.
#
# ![title](capturas/conference-ontology-model.png)

# %% [markdown]
# ## DIMENSIONAMIENTO DE LOS DATOS RDF

# %% [markdown]
# ### Obtención de la dimensión o cantidad de clases que existen

# %%
endPoint = "http://DESKTOP-3KNOEN3:7200/repositories/PROYECTO"
sparql = SPARQLWrapper(endPoint)

def getClassesDimention():
    query = """
    PREFIX person: <https://w3id.org/scholarlydata/person/>
    PREFIX conf: <https://w3id.org/scholarlydata/ontology/conference-ontology.owl#>
    SELECT DISTINCT ?class (count(?class) as ?count)
    WHERE{
     [ ] a ?class.
    
        FILTER(regex(str(?class), 'https://w3id.org/scholarlydata/ontology/conference-ontology.owl#', 'i')) 

    }GROUP BY ?class
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return sparql.query().convert()

results = getClassesDimention()
df = json_normalize(results["results"]["bindings"]) #Res
df
# Out:
#    class.type                                        class.value  \
# 0         uri  https://w3id.org/scholarlydata/ontology/confer...
# 1         uri  https://w3id.org/scholarlydata/ontology/confer...
# 2         uri  https://w3id.org/scholarlydata/ontology/confer...
# 3         uri  https://w3id.org/scholarlydata/ontology/confer...
# 4         uri  https://w3id.org/scholarlydata/ontology/confer...
# 5         uri  https://w3id.org/scholarlydata/ontology/confer...
# 6         uri  https://w3id.org/scholarlydata/ontology/confer...
# 7         uri  https://w3id.org/scholarlydata/ontology/confer...
# 8         uri  https://w3id.org/scholarlydata/ontology/confer...
# 9         uri  https://w3id.org/scholarlydata/ontology/confer...
# 10        uri  https://w3id.org/scholarlydata/ontology/confer...
# 11        uri  https://w3id.org/scholarlydata/ontology/confer...
# 12        uri  https://w3id.org/scholarlydata/ontology/confer...
# 13        uri  https://w3id.org/scholarlydata/ontology/confer...
# 14        uri  https://w3id.org/scholarlydata/ontology/confer...
# 15        uri  https://w3id.org/scholarlydata/ontology/confer...
# 16        uri  https://w3id.org/scholarlydata/ontology/confer...
# 17        uri  https://w3id.org/scholarlydata/ontology/confer...
# 18        uri  https://w3id.org/scholarlydata/ontology/confer...
# 19        uri  https://w3id.org/scholarlydata/ontology/confer...
# 20        uri  https://w3id.org/scholarlydata/ontology/confer...
#
#                               count.datatype count.type count.value
# 0   http://www.w3.org/2001/XMLSchema#integer    literal        5884
# 1   http://www.w3.org/2001/XMLSchema#integer    literal       19592
# 2   http://www.w3.org/2001/XMLSchema#integer    literal       11744
# 3   http://www.w3.org/2001/XMLSchema#integer    literal        3358
# 4   http://www.w3.org/2001/XMLSchema#integer    literal       20903
# 5   http://www.w3.org/2001/XMLSchema#integer    literal        4030
# 6   http://www.w3.org/2001/XMLSchema#integer    literal        5757
# 7   http://www.w3.org/2001/XMLSchema#integer    literal       10311
# 8   http://www.w3.org/2001/XMLSchema#integer    literal           7
# 9   http://www.w3.org/2001/XMLSchema#integer    literal           5
# 10  http://www.w3.org/2001/XMLSchema#integer    literal         306
# 11  http://www.w3.org/2001/XMLSchema#integer    literal          40
# 12  http://www.w3.org/2001/XMLSchema#integer    literal          18
# 13  http://www.w3.org/2001/XMLSchema#integer    literal          35
# 14  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 15  http://www.w3.org/2001/XMLSchema#integer    literal          84
# 16  http://www.w3.org/2001/XMLSchema#integer    literal          13
# 17  http://www.w3.org/2001/XMLSchema#integer    literal          78
# 18  http://www.w3.org/2001/XMLSchema#integer    literal           5
# 19  http://www.w3.org/2001/XMLSchema#integer    literal          12
# 20  http://www.w3.org/2001/XMLSchema#integer    literal          12

# %%
df['class'] = df['class.value'].str.lstrip('https://w3id.org/scholarlydata/ontology/conference-ontology.owl#')

# %%
df['count.value'] = df['count.value'].astype(int)
print(type(df["count.value"][0]))

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

sns.catplot(x="class", y="count.value", kind="bar", data=df, size=30)
# Out:
# <class 'numpy.int32'>
# c:\users\juanj\appdata\local\programs\python\python37\lib\site-packages\seaborn\categorical.py:3747: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
print(df['class'])
# Out:
# 0                       List
# 1                   ListItem
# 2                     Person
# 3             OrganisedEvent
# 4     AffiliationDuringEvent
# 5               Organisation
# 6              InProceedings
# 7            RoleDuringEvent
# 8                 Conference
# 9                Proceedings
# 10                      Talk
# 11                     Track
# 12             AcademicEvent
# 13               SocialEvent
# 14            PublishingRole
# 15                   Session
# 16                  Tutorial
# 17                  Workshop
# 18                     Panel
# 19                      Meal
# 20                     Break
# Name: class, dtype: object

# %% [markdown]
# ### Cantidad de propiedades que existen en la Ontologia

# %%
def getPropertiesDimention():
    query = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX person: <https://w3id.org/scholarlydata/person/>
    PREFIX conf: <https://w3id.org/scholarlydata/ontology/conference-ontology.owl#>

    SELECT DISTINCT ?prop
    WHERE {
        # ?prop a rdf:Property
    }
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return sparql.query().convert()

results = getPropertiesDimention()
df2 = json_normalize(results["results"]["bindings"]) #Res
df2['prop'] = df2['prop.value'].str.lstrip("#")
print(df2['prop'])
# Out:
# 0       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1     http://www.w3.org/2000/01/rdf-schema#subProper...
# 2       http://www.w3.org/2000/01/rdf-schema#subClassOf
# 3           http://www.w3.org/2000/01/rdf-schema#domain
# 4            http://www.w3.org/2000/01/rdf-schema#range
#                             ...
# 62    https://w3id.org/scholarlydata/ontology/confer...
# 63    https://w3id.org/scholarlydata/ontology/confer...
# 64                       http://xmlns.com/foaf/0.1/made
# 65    https://w3id.org/scholarlydata/ontology/confer...
# 66                  http://xmlns.com/foaf/0.1/givenName
# Name: prop, Length: 67, dtype: object

# %%
def getPapers():
    query = """
    PREFIX person: <https://w3id.org/scholarlydata/person/>
    PREFIX conf: <https://w3id.org/scholarlydata/ontology/conference-ontology.owl#>
    SELECT DISTINCT ?paper ?title ?person ?name
    WHERE{
      # ?paper a conf:InProceedings;
        conf:hasAuthorList ?authorList;
        conf:title ?title . 
      # ?authorList conf:hasFirstItem ?item .
      # ?item conf:hasContent ?person .
      # ?person conf:name ?name
    }
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return sparql.query().convert()

results = getPapers()
df3 = json_normalize(results["results"]["bindings"]) #Res
df3
# Out:
#      paper.type                                        paper.value title.type  \
# 0           uri  https://w3id.org/scholarlydata/inproceedings/c...    literal
# 1           uri  https://w3id.org/scholarlydata/inproceedings/c...    literal
# 2           uri  https://w3id.org/scholarlydata/inproceedings/c...    literal
# 3           uri  https://w3id.org/scholarlydata/inproceedings/c...    literal
# 4           uri  https://w3id.org/scholarlydata/inproceedings/c...    literal
# ...         ...                                                ...        ...
# 6170        uri  https://w3id.org/scholarlydata/inproceedings/x...    literal
# 6171        uri  https://w3id.org/scholarlydata/inproceedings/x...    literal
# 6172        uri  https://w3id.org/scholarlydata/inproceedings/x...    literal
# 6173        uri  https://w3id.org/scholarlydata/inproceedings/x...    literal
# 6174        uri  https://w3id.org/scholarlydata/inproceedings/x...    literal
#
#                                             title.value person.type  \
# 0     Identifying Information Needs by Modelling Col...         uri
# 1     Incremental SPARQL Evaluation for Query Answer...         uri
# 2     LODWheel – JavaScript-based Visualization of R...         uri
# 3     The Information Workbench as a Self-Service Pl...         uri
# 4                             Towards Green Linked Data         uri
# ...                                                 ...         ...
# 6170  Extraction of Onomatopoeia Used for Foods from...         uri
# 6171  Solution Mining for specific contextualised pr...         uri
# 6172  Extraction of procedural knowledge from the We...         uri
# 6173  Collecting, reusing and executing private work...         uri
# 6174       Contextual Trace-Based Video Recommendations         uri
#
#                                            person.value name.type  \
# 0     https://w3id.org/scholarlydata/person/khadija-...   literal
# 1     https://w3id.org/scholarlydata/person/florian-...   literal
# 2     https://w3id.org/scholarlydata/person/magnus-s...   literal
# 3     https://w3id.org/scholarlydata/person/peter-haase   literal
# 4     https://w3id.org/scholarlydata/person/julia-hoxha   literal
# ...                                                 ...       ...
# 6170   https://w3id.org/scholarlydata/person/ayumi-kato   literal
# 6171  https://w3id.org/scholarlydata/person/christia...   literal
# 6172  https://w3id.org/scholarlydata/person/pol-schu...   literal
# 6173  https://w3id.org/scholarlydata/person/sebastia...   literal
# 6174  https://w3id.org/scholarlydata/person/raafat-z...   literal
#
#                    name.value
# 0          Khadija Elbedweihy
# 1          Florian Schmedding
# 2                Magnus Stuhr
# 3                 Peter Haase
# 4                 Julia Hoxha
# ...                       ...
# 6170               Ayumi Kato
# 6171  Christian Severin Sauer
# 6172           Pol Schumacher
# 6173           Sebastian Görg
# 6174             Raafat Zarka
#
# [6175 rows x 8 columns]

# %%
df3['name'] = df3['name.value']

# %%
p = df3.groupby('title.value').name.nunique().reset_index()
print(p.sort_values(by=['name'], ascending=False))
# Out:
#                                             title.value  name
# 4491  Summary Models for Routing Keywords to Linked ...     7
# 2354  IBSE: An OWL Interoperability Evaluation Infra...     6
# 4731     The Object with States Ontology Design Pattern     6
# 2236  Guidelines for Benchmarking the Performance of...     6
# 3384  Ontology-based Interpretation of Keywords for ...     5
# ...                                                 ...   ...
# 1909  Exploring Semantic Features for Producing Top-...     1
# 1908             Exploring Scholarly Data with Rexplore     1
# 1907                Exploring RDF/S KBs Using Summaries     1
# 1906         Exploring Linked Open Data with Tag Clouds     1
# 5495  ♠ Demo: An Open Source Tool for Partial Parsin...     1
#
# [5496 rows x 2 columns]

# %% [markdown]
# ## Papers relacionados con SPARQL o RDF

# %%
def getPapers():
    query = """
    PREFIX person: <https://w3id.org/scholarlydata/person/>
    PREFIX conf: <https://w3id.org/scholarlydata/ontology/conference-ontology.owl#>
    SELECT DISTINCT ?paper ?title ?abstract
    WHERE{
       VALUES ?tipoPaper{'SPARQL' 'RDF'}
      # ?paper a conf:InProceedings;
        conf:hasAuthorList ?authorList;
        conf:title ?title;
        conf:abstract ?abstract. 
       filter contains(UCASE(?title), ?tipoPaper) 
    }
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return sparql.query().convert()

results = getPapers()
df4 = json_normalize(results["results"]["bindings"]) #Res
#df4 = df4['title.value']

# %%
df4
# Out:
#     paper.type                                        paper.value title.type  \
# 0          uri  https://w3id.org/scholarlydata/inproceedings/e...    literal
# 1          uri  https://w3id.org/scholarlydata/inproceedings/e...    literal
# 2          uri  https://w3id.org/scholarlydata/inproceedings/e...    literal
# 3          uri  https://w3id.org/scholarlydata/inproceedings/e...    literal
# 4          uri  https://w3id.org/scholarlydata/inproceedings/e...    literal
# ..         ...                                                ...        ...
# 382        uri  https://w3id.org/scholarlydata/inproceedings/w...    literal
# 383        uri  https://w3id.org/scholarlydata/inproceedings/w...    literal
# 384        uri  https://w3id.org/scholarlydata/inproceedings/w...    literal
# 385        uri  https://w3id.org/scholarlydata/inproceedings/w...    literal
# 386        uri  https://w3id.org/scholarlydata/inproceedings/w...    literal
#
#                                            title.value abstract.type  \
# 0    Freshening Up While Staying Fast: Towards Hybr...       literal
# 1    Vocabulary Services Based on SPARQL Endpoints:...       literal
# 2    Flexible RDF generation from RDF and heterogen...       literal
# 3    Extraction and Visualization of TBox Informati...       literal
# 4    An Evolutionary Algorithm to Learn SPARQL Quer...       literal
# ..                                                 ...           ...
# 382  D2RQ/Update: Updating Relational Data via Virt...       literal
# 383  On Directly Mapping Relational Databases to RD...       literal
# 384  Getting More RDF Support from Relational Datab...       literal
# 385  Binary RDF for Scalable Publishing, Exchanging...       literal
# 386  A JavaScript RDF store and application library...       literal
#
#                                         abstract.value
# 0    Linked Data querying over cached indexes of We...
# 1    Vocabularies are an integral part of Linked Da...
# 2    RDF aims at being the universal abstract data ...
# 3    The growing amount of data being published as ...
# 4    Efficient usage of the knowledge provided by t...
# ..                                                 ...
# 382  D2RQ is a popular RDB-to-RDF mapping platform ...
# 383  Mapping relational databases to RDF is a funda...
# 384  We introduce the database fragment of RDF, whi...
# 385  The Web of Data is producing increasingly larg...
# 386  In this paper we present a pure JavaScript imp...
#
# [387 rows x 6 columns]

# %% [markdown]
# ### Obtener anotaciones del Abstract mediante dbpedia Spotlight

# %%
import spotlight 
from functools import partial

endpoint = 'https://api.dbpedia-spotlight.org/en/'


text = df4['abstract.value'][0]

def getAnnotations(text, confidence=0.4, support=20):
    
    annotations = spotlight.annotate(endpoint + 'annotate', text, confidence=confidence, support=support)
    listAnn = []
    for a in annotations:
        listAnn.append([a['URI'], a['support'], a['types'], a['surfaceForm'], a['similarityScore']])
    return listAnn

print(getAnnotations(text))
# Out:
# [['http://dbpedia.org/resource/Linked_data', 256, '', 'Linked Data', 1.0], ['http://dbpedia.org/resource/Cache_coherence', 182, '', 'cached', 0.9998825725527143], ['http://dbpedia.org/resource/Runtime_system', 446, '', 'runtime', 0.9999992261688969], ['http://dbpedia.org/resource/Hybrid_electric_vehicle', 1356, '', 'hybrid', 0.8955368841098621], ['http://dbpedia.org/resource/Linked_data', 256, '', 'Linked Data', 1.0], ['http://dbpedia.org/resource/Hybrid_electric_vehicle', 1356, '', 'hybrid', 0.8955368841098621], ['http://dbpedia.org/resource/Cache_coherence', 182, '', 'cached', 0.9998825725527143], ['http://dbpedia.org/resource/Black_box', 323, '', 'black boxes', 0.9999999892345387], ['http://dbpedia.org/resource/Hybrid_electric_vehicle', 1356, '', 'hybrid', 0.8955368841098621], ['http://dbpedia.org/resource/Cache_coherence', 182, '', 'cached', 0.9998825725527143], ['http://dbpedia.org/resource/Linked_data', 256, '', 'Linked Data', 1.0]]

# %%
listaPapersAnnotations = []
for index, row in df4.iterrows():
    #getAnnotations(row['abstract.value'])
    listaPapersAnnotations.append([row['paper.value'], getAnnotations(row['abstract.value'])])
    #print(row['abstract.value'])

# %%
print(listaPapersAnnotations[0])
# Out:
# ['https://w3id.org/scholarlydata/inproceedings/ekaw2012/paper/research/71', [['http://dbpedia.org/resource/Linked_data', 256, '', 'Linked Data', 1.0], ['http://dbpedia.org/resource/Cache_coherence', 182, '', 'cached', 0.9998825725527143], ['http://dbpedia.org/resource/Runtime_system', 446, '', 'runtime', 0.9999992261688969], ['http://dbpedia.org/resource/Hybrid_electric_vehicle', 1356, '', 'hybrid', 0.8955368841098621], ['http://dbpedia.org/resource/Linked_data', 256, '', 'Linked Data', 1.0], ['http://dbpedia.org/resource/Hybrid_electric_vehicle', 1356, '', 'hybrid', 0.8955368841098621], ['http://dbpedia.org/resource/Cache_coherence', 182, '', 'cached', 0.9998825725527143], ['http://dbpedia.org/resource/Black_box', 323, '', 'black boxes', 0.9999999892345387], ['http://dbpedia.org/resource/Hybrid_electric_vehicle', 1356, '', 'hybrid', 0.8955368841098621], ['http://dbpedia.org/resource/Cache_coherence', 182, '', 'cached', 0.9998825725527143], ['http://dbpedia.org/resource/Linked_data', 256, '', 'Linked Data', 1.0]]]

# %%
print(str(df4['abstract.value'][0]),"->",str(df4['paper.value'][0]))
# Out:
# Linked Data querying over cached indexes of Web data often suffers from stale or missing results due to infrequent updates and partial coverage of available sources. Conversely, live decentralised approaches offer fresh results taken directly from the Web, but suffer from slow response times due to the expense of numerous remote lookups at runtime. We thus propose a hybrid query approach that improves upon both paradigms, offering fresher results from a broader range of sources than Linked Data caches while offering faster results than live querying. Our hybrid query engine takes a cached and live query engine as black boxes, where a hybrid query planner splits an input query and delegates the appropriate sub-queries to each interface. In this paper, we discuss the core query-planning issues and their main strengths and weaknesses. We also present coherence measures to quantify the coverage and freshness for cached indexes of Linked Data, and show how these measures can be used during query planning to maximise the trade-off between fresh results and fast query execution. -> https://w3id.org/scholarlydata/inproceedings/ekaw2012/paper/research/71
